# %% [markdown]
# Описание программы

# %%
print ("Hello, World!")
print("Добавляю новую строку чтобы ветка отличалась от ветки main и чтобы можно было сделать pull request")
print("Добавляю новую еще одну строку чтобы ветка отличалась от ветки main и чтобы можно было сделать pull request")
